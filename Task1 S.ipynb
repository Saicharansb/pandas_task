# %%
import numpy as np
import pandas as pd

# %%
agent_data = pd.read_csv('AgentPerformance.csv')

# %%
agent_data.head()
# Out:
#   Agent Performance Report  Unnamed: 1     Unnamed: 2   Unnamed: 3  \
# 0                    SL No        Date     Agent Name  Total Chats
# 1                        1  2022-07-30   Prerna Singh           11
# 2                        2  2022-07-30  Nandani Gupta           11
# 3                        3  2022-07-30     Ameya Jain           14
# 4                        4  2022-07-30  Mahesh Sarade           14
#
#               Unnamed: 4               Unnamed: 5      Unnamed: 6  \
# 0  Average Response Time  Average Resolution Time  Average Rating
# 1               00:00:38                 00:04:20            4.11
# 2               00:01:15                 00:28:25            3.14
# 3               00:00:30                 00:11:36            4.55
# 4               00:01:04                 00:15:46            4.71
#
#        Unnamed: 7
# 0  Total Feedback
# 1               9
# 2               7
# 3              11
# 4               7

# %%
df= pd.read_excel('AgentPerformance (1).xlsx')

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback
# 0                  9
# 1                  7
# 2                 11
# 3                  7
# 4                  6
# ...              ...
# 2155               0
# 2156               0
# 2157               0
# 2158               0
# 2159               0
#
# [2160 rows x 8 columns]

# %%
df1 =pd.read_excel("D:\pandas\Agent_Login_Report.xlsx")
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
#Q1.Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave.

# %%
df['date'] = pd.to_datetime(df['Date']) # here we have converted and created date column from object to datetime 64 type

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback       date
# 0                  9 2022-07-30
# 1                  7 2022-07-30
# 2                 11 2022-07-30
# 3                  7 2022-07-30
# 4                  6 2022-07-30
# ...              ...        ...
# 2155               0 2022-07-01
# 2156               0 2022-07-01
# 2157               0 2022-07-01
# 2158               0 2022-07-01
# 2159               0 2022-07-01
#
# [2160 rows x 9 columns]

# %%
df.dtypes
# Out:
# SL No                               int64
# Date                               object
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# date                       datetime64[ns]
# dtype: object

# %%
df.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30

# %%
df['date_week']=df['date'].dt.isocalendar().week

# %%
df['date_week']
# Out:
# 0       30
# 1       30
# 2       30
# 3       30
# 4       30
#         ..
# 2155    26
# 2156    26
# 2157    26
# 2158    26
# 2159    26
# Name: date_week, Length: 2160, dtype: UInt32

# %%
df['date_days']=df['date'].dt.day

# %%
df.tail()
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 2155              00:00:00                00:00:00             0.0
# 2156              00:00:00                00:00:00             0.0
# 2157              00:00:00                00:00:00             0.0
# 2158              00:00:00                00:00:00             0.0
# 2159              00:00:00                00:00:00             0.0
#
#       Total Feedback       date  date_week  date_days
# 2155               0 2022-07-01         26          1
# 2156               0 2022-07-01         26          1
# 2157               0 2022-07-01         26          1
# 2158               0 2022-07-01         26          1
# 2159               0 2022-07-01         26          1

# %%
df_mean = df.groupby(['Agent Name', 'date_week'])['Average Rating'].mean().to_frame()

# %%
df_mean
# Out:
#                       Average Rating
# Agent Name date_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %%
df_mean.to_csv('mean_avg_try.csv')

# %% [raw]
# # Above is the data frame of average rating on weekly basis.

# %%
#2 .Total working days for each agents

# %%
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
# df1.groupby('Agent')['Date'].count()
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1.loc[df1['Agent']== 'Shivananda Sonwane']
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 49      50  Shivananda Sonwane  29-Jul-22  09:00:59 PM  03:02:39 AM  06:01:39
# 68      69  Shivananda Sonwane  29-Jul-22  06:16:18 PM  06:32:59 PM  00:16:41
# 73      74  Shivananda Sonwane  29-Jul-22  05:48:16 PM  05:48:30 PM  00:00:13
# 154    155  Shivananda Sonwane  29-Jul-22  12:42:46 AM  01:12:04 AM  00:29:17
# 163    164  Shivananda Sonwane  28-Jul-22  11:06:17 PM  11:37:07 PM  00:30:50
# 280    281  Shivananda Sonwane  27-Jul-22  08:44:27 PM  03:11:04 AM  06:26:36
# 311    312  Shivananda Sonwane  27-Jul-22  04:08:35 PM  04:30:33 PM  00:21:57
# 398    399  Shivananda Sonwane  26-Jul-22  08:57:05 PM  03:09:35 AM  06:12:29
# 485    486  Shivananda Sonwane  25-Jul-22  08:59:33 PM  03:02:55 AM  06:03:21
# 548    549  Shivananda Sonwane  24-Jul-22  11:54:19 PM  02:07:20 AM  02:13:00
# 571    572  Shivananda Sonwane  24-Jul-22  04:15:34 PM  04:23:21 PM  00:07:46
# 635    636  Shivananda Sonwane  23-Jul-22  09:03:09 PM  03:04:14 AM  06:01:04
# 717    718  Shivananda Sonwane  22-Jul-22  08:40:09 PM  03:05:13 AM  06:25:04
# 932    933  Shivananda Sonwane  20-Jul-22  08:58:56 PM  03:02:06 AM  06:03:09

# %%
df1.groupby('Agent')['Date'].count()
# Out:
# Agent
# Aditya Shinde               1
# Aditya_iot                  9
# Amersh                      4
# Ameya Jain                 10
# Ankitjha                    4
# Anurag Tiwari              37
# Aravind                    10
# Ayushi Mishra              18
# Bharath                     9
# Boktiar Ahmed Bappy        17
# Chaitra K Hiremath         13
# Deepranjan Gupta           58
# Dibyanshu                 208
# Harikrishnan Shaji         23
# Hrisikesh Neogi            37
# Hyder Abbas                 2
# Ineuron Intelligence        1
# Ishawant Kumar             49
# Jawala Prakash             16
# Jaydeep Dixit              11
# Khushboo Priya             18
# Madhulika G                17
# Mahesh Sarade              36
# Maitry                      5
# Manjunatha A                8
# Mithun S                   14
# Mukesh                      3
# Muskan Garg                12
# Nandani Gupta              11
# Nishtha Jain               18
# Nitin M                     1
# Prabir Kumar Satapathy     26
# Prateek _iot               17
# Prerna Singh               18
# Rishav Dash                12
# Saikumarreddy N            10
# Sanjeev Kumar              20
# Saurabh Shukla             40
# Shiva Srivastava           15
# Shivan K                   36
# Shivananda Sonwane         15
# Shubham Sharma             35
# Sowmiya Sivakumar          24
# Sudhanshu Kumar            11
# Suraj S Bilgi               5
# Swati                       5
# Tarun                       1
# Wasim                      20
# Zeeshan                    10
# Name: Date, dtype: int64

# %%
df1['Agent'] = df1['Agent'].str.lstrip('Agent')  # trying to remove spaces in Agent

# %%
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM   02:04:10
# 1        2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM   00:00:17
# 2        3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM   00:45:06
# 4        5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM   01:08:36
# ..     ...                 ...        ...          ...          ...        ...
# 995    996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM   05:58:37
# 996    997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM   06:00:43
# 997    998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM   05:27:34
# 998    999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM   05:16:38
# 999   1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1.loc[df1['Agent']== 'Tarun']
# Out:
# Empty DataFrame
# Columns: [SL No, Agent, Date, Login Time, Logout Time, Duration]
# Index: []

# %%
#3. Total query that you have taken

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback       date  date_week  date_days
# 0                  9 2022-07-30         30         30
# 1                  7 2022-07-30         30         30
# 2                 11 2022-07-30         30         30
# 3                  7 2022-07-30         30         30
# 4                  6 2022-07-30         30         30
# ...              ...        ...        ...        ...
# 2155               0 2022-07-01         26          1
# 2156               0 2022-07-01         26          1
# 2157               0 2022-07-01         26          1
# 2158               0 2022-07-01         26          1
# 2159               0 2022-07-01         26          1
#
# [2160 rows x 11 columns]

# %%
df.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
# t.to_csv('t.csv')

# %%
#4. Total Feedback that you have received

# %%
df.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
#5. Agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating']>3.5) &( df['Average Rating']<4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 76            Prateek _iot
# 78            Nandani Gupta
# 80            Jaydeep Dixit
#                ...
# 1869    Boktiar Ahmed Bappy
# 1874          Ayushi Mishra
# 1941         Jawala Prakash
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# Name: Agent Name, Length: 78, dtype: object

# %%
#6 . Agent name who have rating lesss then 3.5

# %%
df[(df['Average Rating']<=3.5)]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1477, dtype: object

# %%
#7 . Agent name who have rating more then 4.5

# %%
df[(df['Average Rating']>4.5)]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
#8 . How many feedaback agents have received more then 4.5 average

# %%
f=df['Average Rating']>4.5

# %%
df.where(f).groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Aditya Shinde              73.0
# Aditya_iot                 43.0
# Ameya Jain                150.0
# Anirudh                     2.0
# Ankitjha                    1.0
# Aravind                   178.0
# Ayushi Mishra              75.0
# Bharath                   231.0
# Boktiar Ahmed Bappy        52.0
# Chaitra K Hiremath          5.0
# Deepranjan Gupta           83.0
# Harikrishnan Shaji         80.0
# Hrisikesh Neogi           183.0
# Ishawant Kumar             79.0
# Jawala Prakash             33.0
# Jayant Kumar                7.0
# Jaydeep Dixit             179.0
# Khushboo Priya            134.0
# Madhulika G                67.0
# Mahesh Sarade              46.0
# Maitry                     81.0
# Manjunatha A              132.0
# Mithun S                   93.0
# Mukesh                     17.0
# Mukesh Rao                  1.0
# Muskan Garg                14.0
# Nandani Gupta              91.0
# Nishtha Jain               18.0
# Prabir Kumar Satapathy     53.0
# Prateek _iot               54.0
# Prerna Singh               82.0
# Rishav Dash                27.0
# Saikumarreddy N           184.0
# Sandipan Saha               1.0
# Sanjeev Kumar             164.0
# Saurabh Shukla              3.0
# Shiva Srivastava            2.0
# Shivan K                  130.0
# Shivananda Sonwane        154.0
# Shubham Sharma            155.0
# Sowmiya Sivakumar          16.0
# Sudhanshu Kumar             2.0
# Suraj S Bilgi               4.0
# Swati                     103.0
# Vivek                       3.0
# Wasim                     156.0
# Zeeshan                    48.0
# Name: Total Feedback, dtype: float64

# %%
#9 . Average weekly response time for each agent

# %%
agent_datatry = pd.read_csv('AgentPerformance.csv',skipinitialspace=False)

# %%
agent_datatry.columns.str.strip()
# Out:
# Index(['Agent Performance Report', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
agent_datatry
# Out:
#      Agent Performance Report  Unnamed: 1          Unnamed: 2   Unnamed: 3  \
# 0                       SL No        Date          Agent Name  Total Chats
# 1                           1  2022-07-30        Prerna Singh           11
# 2                           2  2022-07-30       Nandani Gupta           11
# 3                           3  2022-07-30          Ameya Jain           14
# 4                           4  2022-07-30       Mahesh Sarade           14
# ...                       ...         ...                 ...          ...
# 2156                     2156  2022-07-01   Sowmiya Sivakumar            0
# 2157                     2157  2022-07-01             Nitin M            0
# 2158                     2158  2022-07-01              Vivek             0
# 2159                     2159  2022-07-01       Ayushi Mishra            0
# 2160                     2160  2022-07-01  Chaitra K Hiremath            0
#
#                  Unnamed: 4               Unnamed: 5      Unnamed: 6  \
# 0     Average Response Time  Average Resolution Time  Average Rating
# 1                  00:00:38                 00:04:20            4.11
# 2                  00:01:15                 00:28:25            3.14
# 3                  00:00:30                 00:11:36            4.55
# 4                  00:01:04                 00:15:46            4.71
# ...                     ...                      ...             ...
# 2156               00:00:00                 00:00:00             0.0
# 2157               00:00:00                 00:00:00             0.0
# 2158               00:00:00                 00:00:00             0.0
# 2159               00:00:00                 00:00:00             0.0
# 2160               00:00:00                 00:00:00             0.0
#
#           Unnamed: 7
# 0     Total Feedback
# 1                  9
# 2                  7
# 3                 11
# 4                  7
# ...              ...
# 2156               0
# 2157               0
# 2158               0
# 2159               0
# 2160               0
#
# [2161 rows x 8 columns]

# %%
#11 . List of all agents name

# %%
set(df['Agent Name'])
# Out:
# {'Abhishek ',
#  'Aditya ',
#  'Aditya Shinde',
#  'Aditya_iot ',
#  'Amersh ',
#  'Ameya Jain',
#  'Anirudh ',
#  'Ankit Sharma',
#  'Ankitjha ',
#  'Anurag Tiwari',
#  'Aravind ',
#  'Ashad Nasim',
#  'Ashish ',
#  'Ayushi Mishra',
#  'Bharath ',
#  'Boktiar Ahmed Bappy',
#  'Chaitra K Hiremath',
#  'Deepranjan Gupta',
#  'Dibyanshu ',
#  'Harikrishnan Shaji',
#  'Hitesh Choudhary',
#  'Hrisikesh Neogi',
#  'Hyder Abbas',
#  'Ineuron Intelligence ',
#  'Ishawant Kumar',
#  'Jawala Prakash',
#  'Jayant Kumar',
#  'Jaydeep Dixit',
#  'Khushboo Priya',
#  'Madhulika G',
#  'Mahak ',
#  'Mahesh Sarade',
#  'Maitry ',
#  'Maneesh ',
#  'Manjunatha A',
#  'Mithun S',
#  'Mukesh ',
#  'Mukesh Rao ',
#  'Muskan Garg',
#  'Nandani Gupta',
#  'Nishtha Jain',
#  'Nitin M',
#  'Prabir Kumar Satapathy',
#  'Prateek _iot ',
#  'Prerna Singh',
#  'Rishav Dash',
#  'Rohan ',
#  'Saif Khan',
#  'Saikumarreddy N',
#  'Samprit ',
#  'Sandipan Saha',
#  'Sanjeev Kumar',
#  'Sanjeevan ',
#  'Saurabh Shukla',
#  'Shiva Srivastava',
#  'Shivan K',
#  'Shivan_S ',
#  'Shivananda Sonwane',
#  'Shubham Sharma',
#  'Sowmiya Sivakumar',
#  'Spuri ',
#  'Sudhanshu Kumar',
#  'Suraj S Bilgi',
#  'Swati ',
#  'Tarun ',
#  'Uday Mishra',
#  'Vasanth P',
#  'Vivek ',
#  'Wasim ',
#  'Zeeshan '}

# %%
#12 . percentage of chat on which they have received a feedback

# %%
df.groupby(['Agent Name','Total Chats'])['Total Feedback'].sum()
# Out:
# Agent Name     Total Chats
# Abhishek       0               0
# Aditya         0               0
# Aditya Shinde  0               0
#                8               7
#                14              9
#                               ..
# Zeeshan        36             28
#                37             25
#                41             25
#                46             28
#                92             35
# Name: Total Feedback, Length: 638, dtype: int64
